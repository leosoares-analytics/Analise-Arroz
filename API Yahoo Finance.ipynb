# %%
import yfinance as yf

# %%
usd = yf.download("USDBRL=X")
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_6360\2661540168.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   usd = yf.download("USDBRL=X")
# [*********************100%***********************]  1 of 1 completed

# %%
usd.head()
# Out:
# Price         Close      High       Low      Open   Volume
# Ticker     USDBRL=X  USDBRL=X  USDBRL=X  USDBRL=X USDBRL=X
# Date
# 2026-05-12   4.9064  4.940031  4.881165  4.906400        0
# 2026-05-13   4.9097  4.952900  4.886403  4.910500        0
# 2026-05-14   5.0249  5.025700  4.971800  5.019843        0
# 2026-05-15   5.0041  5.102200  4.977981  4.998740        0
# 2026-05-18   5.0604  5.066800  5.007700  5.060600        0
